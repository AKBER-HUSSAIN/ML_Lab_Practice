# %% [markdown]
# <a href="https://colab.research.google.com/github/AKBER-HUSSAIN/ML_Lab_Practice/blob/main/clustering_programs/diffrent_Linkages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster


X, y = make_blobs(n_samples=100, centers=3, cluster_std=1.2, random_state=42)

linkage_methods = ['single', 'complete', 'average', 'ward', 'centroid']

for method in linkage_methods:
    linked = linkage(X, method=method)
    plt.figure(figsize=(8, 4))
    dendrogram(linked)
    plt.title(f"Hierarchical Clustering - {method.capitalize()} Linkage")
    plt.xlabel("Samples")
    plt.ylabel("Distance")
    plt.show()

    # Form clusters (optional)
    labels = fcluster(linked, t=3, criterion='maxclust')
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
    plt.title(f"{method.capitalize()} Linkage Clustering Result")
    plt.show()
